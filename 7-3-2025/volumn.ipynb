# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('bank.csv')
df.head()
# Out:
#          Date          Company Symbol    Open    High    Low   Close    Volume
# 0  2025-07-01   JPMorgan Chase    JPM  148.35  150.22  147.8  149.50  12100000
# 1  2025-07-01  Bank of America    BAC   38.40   39.10   38.0   38.85   9800000
# 2  2025-07-01      Wells Fargo    WFC   42.25   43.00   41.9   42.75   8700000
# 3  2025-07-01        Citigroup      C   54.90   55.50   54.1   55.05   7600000
# 4  2025-07-01    Goldman Sachs     GS  382.00  385.70  380.5  384.25   5100000

# %%
plt.pie(df['Volume'],labels=df['Date'])
plt.title("volumn of stock")

plt.show()
