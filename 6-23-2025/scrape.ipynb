# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url="https://www.thebritishcollege.edu.np/programme"

# %%
response=requests.get(url)
response
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(response.text,'html')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html data-bs-theme="light" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="" name="cube-desc">
# <meta content="FA476E667ABF159650910B41C9420203" name="msvalidate.01">
# <meta content="NP" name="distribution"/>
# <meta content="Education" name="classification"/>
# <meta content="7 Days" name="revisit-after"/>
# <meta content="Index, Follow" name="robots"/>
# <meta content="The British College" name="author"/>
# <meta content="Education Courses" name="application-name"/>
# <meta content="EN" http-equiv="content-language"/>
# <meta content="E-Worksuk" name="designer"/>
# <meta content="The British College" name="DC.title"/>
# <meta content="NP-BA" name="geo.region"/>
# <meta content="Kathmandu" name="geo.placename"/>
# <meta content="27.693123;85.319173" name="geo.position"/>
# <meta content="27.693123, 85.319173" name="ICBM"/>
# ...

# %%
courses=soup.find_all("div",attrs={"class":"course-title d-flex align-items-center"})
courses
# Out:
# [<div class="course-title d-flex align-items-center">
#  <a href="https://www.thebritishcollege.edu.np/programme/BBA-college-in-kathmandu-nepal"><div class="border" style="background: #00aeef;"></div></a>
#  <h3 style="color: #00aeef">BBA (Hons) Business and Management</h3>
#  </div>,
#  <div class="course-title d-flex align-items-center">
#  <a href="https://www.thebritishcollege.edu.np/programme/ba-hons-hospitality-management"><div class="border" style="background: #333;"></div></a>
#  <h3 style="color: #333">BA (Hons) Hospitality Management (BHM)</h3>
#  </div>,
#  <div class="course-title d-flex align-items-center">
#  <a href="https://www.thebritishcollege.edu.np/programme/bsc-computing-BIT-in-kathmandu-nepal"><div class="border" style="background: #2b3a8c;"></div></a>
#  <h3 style="color: #2b3a8c">BSc (Hons) Computing</h3>
#  </div>,
#  <div class="course-title d-flex align-items-center">
# ...

# %%
module=[]
for x in courses:
    module.append( x.text.strip())
# Out:
# BBA (Hons) Business and Management
# BA (Hons) Hospitality Management (BHM)
# BSc (Hons) Computing
# BSc (Hons) Cyber Security and Digital Forensics
# BSc (Hons) Computer Science - Artificial Intelligence
# BSc (Hons) Data Science
# BBA (Hons) Business and Management
# BA (Hons) Hospitality Management (BHM)
# BSc (Hons) Computing
# BSc (Hons) Cyber Security and Digital Forensics
# BSc (Hons) Computer Science - Artificial Intelligence
# BSc (Hons) Data Science
# Weekend MBA (Executive)
# MBA (Graduate)
# MSc in Professional Accountancy
# MSc Information and Technology
# MSc Advanced Computer Science
# Weekend MBA (Executive)
# MBA (Graduate)
# MSc in Professional Accountancy
# MSc Information and Technology
# MSc Advanced Computer Science
# GCE A Level
# ACCA Programme
# Pearson Test of English (PTE) Academic
# Level 2 Diploma in Food Preparation - Patisserie
# Skills Proficiency Awards in Basic Food Preparation
# GCE A Level
# ACCA Programme
# Pearson Test of English (PTE) Academic
# ...
